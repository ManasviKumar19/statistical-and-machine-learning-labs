# %%
from sklearn.linear_model import LogisticRegressionCV
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Lasso, Ridge, ElasticNet
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import make_pipeline
from sklearn.metrics import accuracy_score
import numpy as np
import pandas as pd

# %%
import pyarrow.feather as feather

# %% [markdown]
# ## Loading the Data

# %% [markdown]
# #### Training Data

# %%
train_data = feather.read_feather("C:/Users/manas/Downloads/masq_train.feather")

# %%
train_data
# Out:
#       D_DEPDYS GENDER  Leeftijd DEMOG1 DEMOG2 DEMOG3 DEMOG4 DEMOG5 DEMOG6  \
# 0            1      v        27      2      5      3      1      6      1
# 1            1      v        59      1      2      2      1      2      1
# 2            0      v        55     NA     NA     NA     NA     NA     NA
# 3            1      v        45      2      4      4      2      6      1
# 4            1      m        58      1      2      1      1      1      1
# ...        ...    ...       ...    ...    ...    ...    ...    ...    ...
# 1793         0      v        44      2      4      2      1      6      1
# 1794         1      m        57      4      2      2      1      6      1
# 1795         1      m        72      1      2      2      1      4      1
# 1796         1      v        48      2      1      4      1      6      1
# 1797         0      m        24      4      5      3      1      5      1
#
#      DEMOG7  ... MASQ81  MASQ82  MASQ83  MASQ84  MASQ85  MASQ86  MASQ87  \
# 0         1  ...      2       1       1       3       1       5       1
# 1         1  ...      4       3       1       3       1       5       2
# 2        NA  ...      1       1       1       1       4       1       1
# 3         1  ...      2       1       1       1       1       5       1
# 4         1  ...      4       4       4       4       4       4       1
# ...     ...  ...    ...     ...     ...     ...     ...     ...     ...
# 1793      1  ...      2       4       2       4       1       5       1
# 1794      1  ...      2       3       1       4       4       5       1
# 1795      1  ...      2       4       4       1       4       5       1
# 1796      1  ...      5       4       5       5       1       5       1
# 1797      1  ...      1       1       1       1       1       5       1
#
#       MASQ88  MASQ89  MASQ90
# 0          3       4       5
# 1          4       1       4
# 2          4       1       2
# 3          2       5       5
# 4          4       2       4
# ...      ...     ...     ...
# 1793       1       1       3
# 1794       2       2       4
# 1795       1       1       4
# 1796       1       5       5
# 1797       3       1       3
#
# [1798 rows x 100 columns]

# %%
train_data.replace(["NA", "NaN", "None"], float("NaN"), inplace=True)
train_data.dropna(inplace=True)

# %%
X_train = train_data.drop(columns=['D_DEPDYS','GENDER'], axis=1)
Y_train = train_data['D_DEPDYS']

# %%
std_scaler = StandardScaler()
Scaled_X_train = std_scaler.fit_transform(X_train)

# %% [markdown]
# #### Test data

# %%
test_data = feather.read_feather("C:/Users/manas/Downloads/masq_test.feather")

# %%
test_data.replace(["NA", "NaN", "None"], float("NaN"), inplace=True)
test_data.dropna(inplace=True)

# %%
X_test = test_data.drop(columns=['D_DEPDYS','GENDER'], axis=1)
Y_test = test_data['D_DEPDYS']

# %%
std_scaler = StandardScaler()
Scaled_X_test = std_scaler.fit_transform(X_test)

# %% [markdown]
# ### Multicollinearity

# %%
masq_items = []

# %%
for i in train_data.columns :
    if i.startswith('MASQ'):
        masq_items.append(i)

# %%
masq_items_col = train_data[masq_items]

# %%
collineraity_mat = masq_items_col.corr()

# %%
collineraity_mat
# Out:
#           MASQ01    MASQ02    MASQ03    MASQ04    MASQ05    MASQ06    MASQ07  \
# MASQ01  1.000000  0.262217  0.265062  0.380913  0.335543  0.474756  0.315556
# MASQ02  0.262217  1.000000  0.608717  0.478178  0.179281  0.438185 -0.001811
# MASQ03  0.265062  0.608717  1.000000  0.502096  0.202690  0.382599 -0.024594
# MASQ04  0.380913  0.478178  0.502096  1.000000  0.213340  0.561569  0.110424
# MASQ05  0.335543  0.179281  0.202690  0.213340  1.000000  0.278225  0.135236
# ...          ...       ...       ...       ...       ...       ...       ...
# MASQ86  0.587306  0.264327  0.249502  0.378310  0.290202  0.434135  0.306033
# MASQ87  0.128830  0.238559  0.270307  0.268544  0.141148  0.208962  0.041781
# MASQ88  0.207448  0.292913  0.354405  0.316389  0.209039  0.242952  0.048697
# MASQ89  0.324105  0.270357  0.260470  0.386688  0.160104  0.428470  0.076493
# MASQ90  0.398467  0.281993  0.322646  0.433322  0.260034  0.433672  0.200156
#
#           MASQ08    MASQ09    MASQ11  ...    MASQ81    MASQ82    MASQ83  \
# MASQ01  0.479949  0.172166  0.540486  ...  0.224389  0.238898  0.277891
# MASQ02  0.408861  0.294180  0.211487  ...  0.243169  0.280581  0.207109
# MASQ03  0.385485  0.329800  0.227690  ...  0.336869  0.340081  0.215435
# MASQ04  0.528397  0.300713  0.291479  ...  0.308149  0.373863  0.239166
# MASQ05  0.244953  0.163066  0.242694  ...  0.180029  0.190420  0.641756
# ...          ...       ...       ...  ...       ...       ...       ...
# MASQ86  0.440462  0.170428  0.564515  ...  0.178069  0.198345  0.214043
# MASQ87  0.206729  0.287024  0.122648  ...  0.271658  0.238203  0.177449
# MASQ88  0.272203  0.303965  0.149199  ...  0.374239  0.278315  0.207560
# MASQ89  0.428600  0.161391  0.244015  ...  0.134511  0.172068  0.167206
# MASQ90  0.431587  0.285803  0.308787  ...  0.413853  0.303054  0.325244
#
#           MASQ84    MASQ85    MASQ86    MASQ87    MASQ88    MASQ89    MASQ90
# MASQ01  0.429284  0.142316  0.587306  0.128830  0.207448  0.324105  0.398467
# MASQ02  0.460370  0.230764  0.264327  0.238559  0.292913  0.270357  0.281993
# MASQ03  0.387407  0.248509  0.249502  0.270307  0.354405  0.260470  0.322646
# MASQ04  0.504445  0.268716  0.378310  0.268544  0.316389  0.386688  0.433322
# MASQ05  0.322225  0.212618  0.290202  0.141148  0.209039  0.160104  0.260034
# ...          ...       ...       ...       ...       ...       ...       ...
# MASQ86  0.410241  0.127133  1.000000  0.128708  0.173450  0.305387  0.371028
# MASQ87  0.225679  0.287911  0.128708  1.000000  0.335287  0.166844  0.264125
# MASQ88  0.270816  0.290134  0.173450  0.335287  1.000000  0.201574  0.332461
# MASQ89  0.307362  0.141278  0.305387  0.166844  0.201574  1.000000  0.319554
# MASQ90  0.423927  0.267123  0.371028  0.264125  0.332461  0.319554  1.000000
#
# [89 rows x 89 columns]

# %% [markdown]
# ## Implementing the models

# %%
lasso = Lasso()
ridge = Ridge()
elastic_net = ElasticNet()

# %%
lasso_hyperparams = {'alpha': [0.01, 0.1, 1, 10]}
ridge_hyperparams = {'alpha': [0.01, 0.1, 1, 10]}
elastic_net_hyperparams = {'alpha': [0.01, 0.1, 1, 10], 'l1_ratio': [0.1, 0.5, 0.9]}

# %% [markdown]
# ### Lasso CV

# %%
lasso_cv = GridSearchCV(lasso, param_grid=lasso_hyperparams, cv=10)
lasso_cv.fit(Scaled_X_train, Y_train)
# Out:
# GridSearchCV(cv=10, estimator=Lasso(), param_grid={'alpha': [0.01, 0.1, 1, 10]})

# %% [markdown]
# ### Ridge CV

# %%
ridge_cv = GridSearchCV(ridge, param_grid=ridge_hyperparams, cv=10)
ridge_cv.fit(Scaled_X_train, Y_train)
# Out:
# GridSearchCV(cv=10, estimator=Ridge(), param_grid={'alpha': [0.01, 0.1, 1, 10]})

# %% [markdown]
# #### Elastic Net CV

# %%
enet_cv = GridSearchCV(elastic_net, param_grid=elastic_net_hyperparams, cv=10)
enet_cv.fit(Scaled_X_train, Y_train)
# Out:
# GridSearchCV(cv=10, estimator=ElasticNet(),
#              param_grid={'alpha': [0.01, 0.1, 1, 10],
#                          'l1_ratio': [0.1, 0.5, 0.9]})

# %% [markdown]
# ### Selecting the best models

# %%
lasso_best = lasso_cv.best_estimator_
ridge_best = ridge_cv.best_estimator_
enet_best = enet_cv.best_estimator_

# %% [markdown]
# ### Performing Prediction

# %% [markdown]
# #### Lasso

# %%
pred_Lasso = lasso_best.predict(Scaled_X_test)

# %% [markdown]
# #### Ridge

# %%
pred_ridge = ridge_best.predict(Scaled_X_test)

# %% [markdown]
# #### Elastic Net

# %%
elastic_net_pred = enet_best.predict(Scaled_X_test)

# %% [markdown]
# ### Accuracy

# %% [markdown]
# #### Lasso

# %%
Lass_acc_score = accuracy_score(Y_test, pred_Lasso.round())
Lass_acc_score
# Out:
# 0.7772667542706965

# %% [markdown]
# #### Ridge

# %%
Ridge_acc_score = accuracy_score(Y_test, pred_ridge.round())
Ridge_acc_score
# Out:
# 0.7752956636005256

# %% [markdown]
# #### Elastic Net

# %%
elnet_acc_score = accuracy_score(Y_test, elastic_net_pred.round())
elnet_acc_score
# Out:
# 0.778580814717477

# %% [markdown]
# ### Extracting the coefficients

# %% [markdown]
# #### Lasso

# %%
MASQ_coeff_lasso = dict(zip(X_train.columns, lasso_best.coef_))
MASQ_coeff_lasso
# Out:
# {'Leeftijd': 0.01479089887927484,
#  'DEMOG1': -0.0,
#  'DEMOG2': -0.0,
#  'DEMOG3': -0.016300475591037006,
#  'DEMOG4': -0.0018809499097131818,
#  'DEMOG5': 0.0005189564630116448,
#  'DEMOG6': 0.0,
#  'DEMOG7': -0.0,
#  'DEMOG8': -0.0,
#  'MASQ01': 0.041216180860564534,
#  'MASQ02': -0.023035078265081693,
#  'MASQ03': -0.010055470719310573,
#  'MASQ04': 0.0,
#  'MASQ05': 9.50174726711432e-05,
#  'MASQ06': 0.0,
#  'MASQ07': 0.0,
#  'MASQ08': -0.0,
#  'MASQ09': 0.0,
#  'MASQ11': 0.0,
#  'MASQ12': -0.0,
#  'MASQ13': 0.01063724087895744,
#  'MASQ14': 0.0023702738145435953,
#  'MASQ15': 0.0,
#  'MASQ16': 0.08281855073828258,
#  'MASQ17': -0.002139427236641269,
#  'MASQ18': 0.0,
#  'MASQ19': 0.0,
#  'MASQ20': -0.0,
#  'MASQ21': 0.0005806067375582409,
#  'MASQ22': 0.04239542131145587,
#  'MASQ23': 0.0,
#  'MASQ24': 0.010210687515838823,
#  'MASQ25': -0.0031180114405663525,
#  'MASQ26': 0.0,
#  'MASQ27': 0.0,
#  'MASQ28': -0.0,
#  'MASQ29': 0.0029588500311477483,
#  'MASQ30': 0.028849751445227063,
#  'MASQ31': 0.01350633702986144,
#  'MASQ32': 0.0,
#  'MASQ33': 0.005472244058410778,
#  'MASQ34': -0.0,
#  'MASQ35': -0.0008182687105379835,
#  'MASQ36': -0.0,
#  'MASQ37': 0.020413097091152858,
#  'MASQ38': 0.006013068483712948,
#  'MASQ39': 0.0060650525146508346,
#  'MASQ40': -0.0,
#  'MASQ41': 0.029283618163289716,
#  'MASQ42': 0.0,
#  'MASQ43': 0.006435947393867151,
#  'MASQ44': 0.0001021407509835736,
#  'MASQ45': 0.0,
#  'MASQ46': 0.0,
#  'MASQ47': -0.0,
#  'MASQ48': -0.0,
#  'MASQ49': 0.0,
#  'MASQ50': 0.0038990455784425494,
#  'MASQ51': 0.0,
#  'MASQ52': 0.0,
#  'MASQ53': 0.0,
#  'MASQ54': 0.0,
#  'MASQ55': -0.0,
#  'MASQ56': 0.0,
#  'MASQ57': 0.0,
#  'MASQ58': -0.0,
#  'MASQ59': -0.01752447007584008,
#  'MASQ60': 0.013669441007034377,
#  'MASQ61': -0.0,
#  'MASQ62': 0.021407030684985884,
#  'MASQ63': -0.0,
#  'MASQ64': -0.0,
#  'MASQ65': -0.0,
#  'MASQ66': -0.0,
#  'MASQ67': 0.0,
#  'MASQ68': 0.0,
#  'MASQ69': -0.0,
#  'MASQ70': 0.006897443555723844,
#  'MASQ71': 0.0,
#  'MASQ72': -0.0,
#  'MASQ73': -0.0,
#  'MASQ74': -0.0,
#  'MASQ75': -0.004936580696087222,
#  'MASQ76': 0.019200745203351664,
#  'MASQ77': 0.0,
#  'MASQ78': 0.009138130684928395,
#  'MASQ79': 0.0,
#  'MASQ80': 0.0,
#  'MASQ81': -0.0,
#  'MASQ82': -0.0,
#  'MASQ83': 0.0,
#  'MASQ84': -0.0,
#  'MASQ85': 0.00025729786693381117,
#  'MASQ86': -0.0,
#  'MASQ87': -0.0,
#  'MASQ88': -0.0,
#  'MASQ89': 0.02985619620854446,
#  'MASQ90': 0.017289588453644214}

# %% [markdown]
# #### Ridge

# %%
MASQ_coeff_ridge = dict(zip(X_train.columns, ridge_best.coef_))
MASQ_coeff_ridge
# Out:
# {'Leeftijd': 0.0037160033610032102,
#  'DEMOG1': -0.009665083609585928,
#  'DEMOG2': -0.005400859476483578,
#  'DEMOG3': -0.024780047416813507,
#  'DEMOG4': -0.0069610970691253915,
#  'DEMOG5': 0.013823710674293643,
#  'DEMOG6': 0.005973934605459416,
#  'DEMOG7': -0.003385946502305092,
#  'DEMOG8': -0.011849564671361659,
#  'MASQ01': 0.04864051143870646,
#  'MASQ02': -0.030031552163509334,
#  'MASQ03': -0.024229876116464297,
#  'MASQ04': 0.010142847691749802,
#  'MASQ05': 0.009364192094218678,
#  'MASQ06': -0.003879945086609907,
#  'MASQ07': -0.0006814810872363259,
#  'MASQ08': -0.022224722627055476,
#  'MASQ09': 0.012152113026813426,
#  'MASQ11': 0.007204322843791639,
#  'MASQ12': -0.01748998394489419,
#  'MASQ13': 0.0447832014393135,
#  'MASQ14': 0.013305652166948682,
#  'MASQ15': 0.014598376979594326,
#  'MASQ16': 0.09862378804802542,
#  'MASQ17': -0.0304684440320716,
#  'MASQ18': 0.009418608109222026,
#  'MASQ19': -0.0016104142823778434,
#  'MASQ20': -0.026684325701459576,
#  'MASQ21': 0.006656358941045628,
#  'MASQ22': 0.05722303953230199,
#  'MASQ23': 0.006323172320380747,
#  'MASQ24': 0.03924112079199059,
#  'MASQ25': -0.021212979116357555,
#  'MASQ26': 0.003929225162203055,
#  'MASQ27': -0.0012937619008698848,
#  'MASQ28': -0.0029437748138042793,
#  'MASQ29': 0.016234995857312313,
#  'MASQ30': 0.039476591270391735,
#  'MASQ31': 0.011830465248008898,
#  'MASQ32': 0.009621022775003192,
#  'MASQ33': 0.001944243826934092,
#  'MASQ34': -0.005466063673380183,
#  'MASQ35': -0.03564086183383556,
#  'MASQ36': -0.0007031449523658655,
#  'MASQ37': 0.020792297524495195,
#  'MASQ38': 0.010199133375254582,
#  'MASQ39': 0.011000022455653092,
#  'MASQ40': -0.02784255747420516,
#  'MASQ41': 0.028440757997413652,
#  'MASQ42': 0.004123623765845448,
#  'MASQ43': 0.025774993819057176,
#  'MASQ44': 0.007355221006371603,
#  'MASQ45': 0.010476203042758191,
#  'MASQ46': 0.0001515670067778397,
#  'MASQ47': -0.029650054465255128,
#  'MASQ48': -0.0004520228771910441,
#  'MASQ49': 0.015159083081562314,
#  'MASQ50': 0.023498403023628205,
#  'MASQ51': -0.005345312351407131,
#  'MASQ52': 0.008852015637608244,
#  'MASQ53': 0.0006633603795002735,
#  'MASQ54': 0.01814189554544618,
#  'MASQ55': -0.0055629225664063486,
#  'MASQ56': -0.0015490150889076989,
#  'MASQ57': 0.008116067062700266,
#  'MASQ58': -0.01998380721986917,
#  'MASQ59': -0.03560318620611905,
#  'MASQ60': 0.025425053490966992,
#  'MASQ61': -0.008717672087247103,
#  'MASQ62': 0.026076182217308657,
#  'MASQ63': -0.0022958382617610383,
#  'MASQ64': -0.0052120579614346515,
#  'MASQ65': -0.014616189479347359,
#  'MASQ66': -0.012676460180255873,
#  'MASQ67': 0.006519440634039385,
#  'MASQ68': -0.00565736581656194,
#  'MASQ69': -0.011000554977013206,
#  'MASQ70': 0.021252202590667454,
#  'MASQ71': -0.005026524984763966,
#  'MASQ72': -0.009396108669685236,
#  'MASQ73': 0.0026533600687573267,
#  'MASQ74': -0.01826309450479933,
#  'MASQ75': -0.019850730112812846,
#  'MASQ76': 0.021238778097401087,
#  'MASQ77': 0.004405657519701269,
#  'MASQ78': 0.022548297952250638,
#  'MASQ79': 0.02063994402872418,
#  'MASQ80': -0.0031496586163566685,
#  'MASQ81': -0.0026327586824458167,
#  'MASQ82': 0.0019364499433392854,
#  'MASQ83': 0.006252526726728896,
#  'MASQ84': -0.02402458335688213,
#  'MASQ85': 0.009333438209992433,
#  'MASQ86': -0.01951098898415161,
#  'MASQ87': 0.007648524336573667,
#  'MASQ88': -0.009616955532992133,
#  'MASQ89': 0.029355588230809432,
#  'MASQ90': 0.03822833138303654}

# %% [markdown]
# #### Elastic Net

# %%
MASQ_coeff_elanet = dict(zip(X_train.columns, enet_best.coef_))
MASQ_coeff_elanet
# Out:
# {'Leeftijd': 0.014793192640770315,
#  'DEMOG1': -0.0,
#  'DEMOG2': -0.0,
#  'DEMOG3': -0.015414998111684118,
#  'DEMOG4': -0.0021918137221413007,
#  'DEMOG5': 0.0005171519091301324,
#  'DEMOG6': 0.0,
#  'DEMOG7': -0.0,
#  'DEMOG8': -0.0,
#  'MASQ01': 0.03706342544720465,
#  'MASQ02': -0.019159994266461193,
#  'MASQ03': -0.009784511801573954,
#  'MASQ04': 0.0,
#  'MASQ05': 0.001010058624440845,
#  'MASQ06': 0.0,
#  'MASQ07': 0.0,
#  'MASQ08': -0.0,
#  'MASQ09': 0.0,
#  'MASQ11': 0.0,
#  'MASQ12': -0.0,
#  'MASQ13': 0.012340359697115905,
#  'MASQ14': 0.005974417556023659,
#  'MASQ15': 0.0,
#  'MASQ16': 0.0683807134930063,
#  'MASQ17': -0.0,
#  'MASQ18': 0.0013681054058610458,
#  'MASQ19': 0.0,
#  'MASQ20': -0.0,
#  'MASQ21': 0.002437242865682775,
#  'MASQ22': 0.037142592395685604,
#  'MASQ23': 0.0,
#  'MASQ24': 0.009955011473571737,
#  'MASQ25': -0.0026142725006029974,
#  'MASQ26': 0.0,
#  'MASQ27': 0.0,
#  'MASQ28': -0.0,
#  'MASQ29': 0.00650219911551528,
#  'MASQ30': 0.02544623631997613,
#  'MASQ31': 0.013118962799443412,
#  'MASQ32': 0.0,
#  'MASQ33': 0.009550735404776826,
#  'MASQ34': -0.0,
#  'MASQ35': -0.0,
#  'MASQ36': 0.0,
#  'MASQ37': 0.01962687382859513,
#  'MASQ38': 0.007198704194784141,
#  'MASQ39': 0.007185058003909797,
#  'MASQ40': -0.0,
#  'MASQ41': 0.026986196462964254,
#  'MASQ42': 0.0,
#  'MASQ43': 0.007620501661741613,
#  'MASQ44': 0.001771506471908515,
#  'MASQ45': 0.0,
#  'MASQ46': 0.0,
#  'MASQ47': -0.0,
#  'MASQ48': -0.0,
#  'MASQ49': 0.0,
#  'MASQ50': 0.004465025460227223,
#  'MASQ51': 0.0,
#  'MASQ52': 0.0,
#  'MASQ53': 0.0,
#  'MASQ54': 0.001645868434966181,
#  'MASQ55': -0.0,
#  'MASQ56': 0.0,
#  'MASQ57': 0.0,
#  'MASQ58': -0.0,
#  'MASQ59': -0.014110461745999564,
#  'MASQ60': 0.013216812135093146,
#  'MASQ61': -0.0,
#  'MASQ62': 0.02063316098954663,
#  'MASQ63': -0.0,
#  'MASQ64': -0.0,
#  'MASQ65': -0.0,
#  'MASQ66': 0.0,
#  'MASQ67': 0.0,
#  'MASQ68': 0.0,
#  'MASQ69': -0.0,
#  'MASQ70': 0.0069873691836677704,
#  'MASQ71': 0.0,
#  'MASQ72': 0.0,
#  'MASQ73': -0.0,
#  'MASQ74': -0.0,
#  'MASQ75': -0.00472417341671742,
#  'MASQ76': 0.018507236713928905,
#  'MASQ77': 0.0,
#  'MASQ78': 0.01036155429549182,
#  'MASQ79': 0.0,
#  'MASQ80': 0.0,
#  'MASQ81': -0.0,
#  'MASQ82': -0.0,
#  'MASQ83': 0.0,
#  'MASQ84': -0.0,
#  'MASQ85': 0.0,
#  'MASQ86': -0.0,
#  'MASQ87': -0.0,
#  'MASQ88': -0.0,
#  'MASQ89': 0.028964697811165036,
#  'MASQ90': 0.016635227449290038}
